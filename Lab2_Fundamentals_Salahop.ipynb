# %%
# [CELL 1] CONFIGURATION

ENGINEER = "Salahop"
STUDENT_ID = "TUPM-25-4175"

# Derivation: Extract the last digit to act as ypur Logic Seed
SEED_NUM = int(STUDENT_ID[-1])

print(f"System Initialized for: {ENGINEER}")
print(f"Algorithmic Seed Value: {SEED_NUM}")
# Out:
# System Initialized for: Salahop
# Algorithmic Seed Value: 5
